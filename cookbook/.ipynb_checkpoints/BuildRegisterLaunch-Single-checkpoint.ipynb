# %%
from flytekit.configuration import platform
def print_console_url(exc):
    print("http://{}/console/projects/{}/domains/{}/executions/{}".format(platform.URL.get(), exc.id.project, exc.id.domain, exc.id.name))

# %% [markdown]
# # REPL-sorta
#
# ### 1) Run locally
# Flyte allows you to run the exact tasks that run remotely locally to iterate, unit test, and fix bugs.

# %%
from workflows.recipe_7.interactive_python import interactive_python

r = interactive_python.unit_test(a=2.0, b=3.0)
print('2+3={}'.format(r['out']))

r = interactive_python.unit_test(a=-5.0, b=3.0)
print('-5+3={}'.format(r['out']))

# %% [markdown]
# ### 2) Build a docker image
# To ensure repeatablity, we recommend building a docker image with a new version to reflect any code change.
#
# Note: You need to have push permissions on a docker hub repo (or any other docker registry) to execute the docker push command.

# %%
from os import environ
environ["version"]="24"
# !docker build -t docker.io/lyft/flytesnacks:datacouncil-$version .
# !docker push docker.io/lyft/flytesnacks:datacouncil-$version
# Out:
# Sending build context to Docker daemon  263.7kB
# Step 1/19 : FROM ubuntu:bionic
#  ---> 775349758637
# Step 2/19 : WORKDIR /root
#  ---> Using cache
#  ---> 9e71f2c2950c
# Step 3/19 : ENV VENV /opt/venv
#  ---> Using cache
#  ---> 7605b00f67e3
# Step 4/19 : ENV LANG C.UTF-8
#  ---> Using cache
#  ---> 197d97963594
# Step 5/19 : ENV LC_ALL C.UTF-8
#  ---> Using cache
#  ---> f424c74f8294
# Step 6/19 : ENV PYTHONPATH /root
#  ---> Using cache
#  ---> ce39083a6d7c
# Step 7/19 : RUN :     && apt-get update && apt-get install -y python3.6 python3.6-venv python3.6-dev make build-essential libssl-dev python3-venv python3-pip curl
#  ---> Using cache
#  ---> fbbef8af0eb2
# Step 8/19 : RUN apt-get update && apt-get install -y libsm6 libxext6 libxrender-dev
#  ---> Using cache
#  ---> 61cfd96195b8
# Step 9/19 : RUN pip3 install awscli
#  ---> Using cache
#  ---> 9ec5fd79ae76
# Step 10/19 : RUN python3.6 -m venv ${VENV}
#  ---> Using cache
#  ---> c9f5e3d2048a
# Step 11/19 : RUN ${VENV}/bin/pip install wheel
#  ---> Using cache
#  ---> 14c2e932b36c
# Step 12/19 : COPY ./requirements.txt /root
#  ---> 20a1c53ff3f4
# Step 13/19 : RUN ${VENV}/bin/pip install -r /root/requirements.txt
#  ---> Running in c90c73422ef0
# Collecting https://github.com/lyft/flytekit/archive/d22499c7c42df9f53ab629f41838cd108f92efc0.zip (from -r /root/requirements.txt (line 7))
#   Downloading https://github.com/lyft/flytekit/archive/d22499c7c42df9f53ab629f41838cd108f92efc0.zip
# Collecting flytekit[schema,sidecar]==0.8.2 (from -r /root/requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/48/d7/c379f837046af8f4e9262f9f8ffda41ea88265d2802573f81012ed9816d8/flytekit-0.8.2-py3-none-any.whl (248kB)
# Collecting pytest (from -r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/9f/f3/0a83558da436a081344aa6c8b85ea5b5f05071214106036ce341b7769b0b/pytest-5.4.3-py3-none-any.whl (248kB)
# Collecting statsd (from -r /root/requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/47/33/c824f799128dfcfce2142f18d9bc6c55c46a939f6e4250639134222d99eb/statsd-3.3.0-py2.py3-none-any.whl
# Collecting opencv-python==3.4.4.19 (from -r /root/requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/85/16/446110984e7a814a9e12862bd6da8d09501d274867b55223e48ee10cd752/opencv_python-3.4.4.19-cp36-cp36m-manylinux1_x86_64.whl (25.4MB)
# Collecting k8s-proto>=0.0.2 (from -r /root/requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/5b/60/daff2df8df7f0eeb2ff428159e3913e7d56b47097ff3d4f50659a264ffbe/k8s-proto-0.0.3.tar.gz (51kB)
# Collecting grpcio==1.27.2 (from -r /root/requirements.txt (line 14))
#   Downloading https://files.pythonhosted.org/packages/f1/97/bece4417f349f8f83252232ef66ea63eb47f8044ca61b51e2a478e2c7a94/grpcio-1.27.2-cp36-cp36m-manylinux1_x86_64.whl (2.7MB)
# Collecting ipython (from -r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/23/6a/210816c943c9aeeb29e4e18a298f14bf0e118fe222a23e13bfcc2d41b0a4/ipython-7.16.1-py3-none-any.whl (785kB)
# Collecting boto3<2.0,>=1.4.4 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/c9/a5/e06492d12da34135728559aa18ba6bc841a82cea5a5b3bcbb643ea2dbe07/boto3-1.14.19-py2.py3-none-any.whl (128kB)
# Collecting click<8.0,>=6.6 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting croniter<4.0.0,>=0.3.20 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9b/83/9b70ce509a225da6b4b1e7779f31c12ee58e26df814d6a03227b1378bf04/croniter-0.3.34-py2.py3-none-any.whl
# Collecting deprecated<2.0,>=1.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/76/a1/05d7f62f956d77b23a640efc650f80ce24483aa2f85a09c03fb64f49e879/Deprecated-1.2.10-py2.py3-none-any.whl
# Collecting flyteidl<1.0.0,>=0.17.34 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9f/e2/da18530a9527f3e2c83937510c2f3833646f5496b3f6bd62b98f6ae53cc9/flyteidl-0.17.36-py3-none-any.whl (111kB)
# Collecting jupyter>=1.0.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting keyring>=18.0.1 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/a8/5e/d13b9feb235d042321a239ac8bc85e90cf3bbe49090c6f1383ac3fd53e0e/keyring-21.2.1-py3-none-any.whl
# Collecting papermill>=1.2.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/dd/d0/b63b84c365bc4f6685e54e27711a8e07c51c7907244165fba5ed882a1be7/papermill-2.1.2-py3-none-any.whl
# Collecting protobuf<4,>=3.6.1 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/28/05/9867ef8eafd12265267bee138fa2c46ebf34a276ea4cbe184cba4c606e8b/protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
# Collecting pyspark>=2.4.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/8e/b0/bf9020b56492281b9c9d8aae8f44ff51e1bc91b3ef5a884385cb4e389a40/pyspark-3.0.0.tar.gz (204.7MB)
# Collecting python-dateutil<=2.8.1,>=2.1 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting pytimeparse<2.0.0,>=1.1.8 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/1b/b4/afd75551a3b910abd1d922dbd45e49e5deeb4d47dc50209ce489ba9844dd/pytimeparse-1.1.8-py2.py3-none-any.whl
# Collecting pytz<2018.5,>=2017.2 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/dc/83/15f7833b70d3e067ca91467ca245bae0f6fe56ddc7451aa0dc5606b120f2/pytz-2018.4-py2.py3-none-any.whl (510kB)
# Collecting requests<3.0.0,>=2.18.4 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
# Collecting responses>=0.10.7 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/06/4c/4cc4a9ad8a592692d579660d9040d5693b30cb066e4ba4159aa4a5e5fb65/responses-0.10.15-py2.py3-none-any.whl
# Collecting six<2.0.0,>=1.9.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting sortedcontainers>=1.5.9<3.0.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/23/8c/22a47a4bf8c5289e4ed946d2b0e4df62bca385b9599cc1e46878f2e2529c/sortedcontainers-2.2.2-py2.py3-none-any.whl
# Collecting urllib3<1.25,>=1.22 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/01/11/525b02e4acc0c747de8b6ccdab376331597c569c42ea66ab0a1dbd36eca2/urllib3-1.24.3-py2.py3-none-any.whl (118kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/82/f7/e43cefbe88c5fd371f4cf0cf5eb3feccd07515af9fd6cf7dbf1d1793a797/wrapt-1.12.1.tar.gz
# Collecting deprecation<3.0,>=2.0 (from flytekit[schema,sidecar]==0.8.2->-r /root/requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl
# Collecting pyarrow<1.0.0,>=0.11.0; extra == "schema" (from flytekit[schema,sidecar]==0.8.2->-r /root/requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/70/9b/38ca9af13cdf5a806d250aea829f1e5e9262ae7e0cfa91cd3679690a8b66/pyarrow-0.17.1-cp36-cp36m-manylinux1_x86_64.whl (64.5MB)
# Collecting pandas<2.0.0,>=0.22.0; extra == "schema" (from flytekit[schema,sidecar]==0.8.2->-r /root/requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c0/95/cb9820560a2713384ef49060b0087dfa2591c6db6f240215c2bce1f4211c/pandas-1.0.5-cp36-cp36m-manylinux1_x86_64.whl (10.1MB)
# Collecting numpy<2.0.0,>=1.14.0; extra == "schema" (from flytekit[schema,sidecar]==0.8.2->-r /root/requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl (13.5MB)
# Collecting pluggy<1.0,>=0.12 (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Collecting packaging (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/46/19/c5ab91b1b05cfe63cccd5cfc971db9214c6dd6ced54e33c30d5af1d2bc43/packaging-20.4-py2.py3-none-any.whl
# Collecting more-itertools>=4.0.0 (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/ef/9b/6c35ec5483710492e21252465160ee508170159f7e0e2d6cd769022f52f6/more_itertools-8.4.0-py3-none-any.whl (43kB)
# Collecting importlib-metadata>=0.12; python_version < "3.8" (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting attrs>=17.4.0 (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting wcwidth (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/59/7c/e39aca596badaf1b78e8f547c807b04dae603a433d3e7a7e04d67f2ef3e5/wcwidth-0.2.5-py2.py3-none-any.whl
# Collecting py>=1.5.0 (from pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/68/0f/41a43535b52a81e4f29e420a151032d26f08b62206840c48d14b70e53376/py-1.9.0-py2.py3-none-any.whl (99kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/e4/a7/81b39aa50e9284fe2cb21cc7fb7de7817b224172d42793fd57451d38842b/prompt_toolkit-3.0.5-py3-none-any.whl (351kB)
# Collecting traitlets>=4.2 (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl (75kB)
# Collecting pexpect; sys_platform != "win32" (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl (59kB)
# Collecting pickleshare (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting pygments (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl (914kB)
# Collecting decorator (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting jedi>=0.10 (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/07/83/7e711550fcb2722f1ca9c8564d5bb23f625ae67d99f4a360b428c0f3e932/jedi-0.17.1-py2.py3-none-any.whl (1.4MB)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.6/site-packages (from ipython->-r /root/requirements.txt (line 15))
# Collecting backcall (from ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/4c/1c/ff6546b6c12603d8dd1070aa3c3d273ad4c07f5771689a7b69a550e8c951/backcall-0.2.0-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3<2.0,>=1.4.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Using cached https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3<2.0,>=1.4.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Using cached https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting botocore<1.18.0,>=1.17.19 (from boto3<2.0,>=1.4.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/e4/33/60eb84ff5dfb26a0c3ae606ba42686f23e9fd5038afddd5882d37623d589/botocore-1.17.19-py2.py3-none-any.whl (6.3MB)
# Collecting natsort (from croniter<4.0.0,>=0.3.20->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/0f/65/81883897f4aaa1e53deaa65137318cfe80b36ce013c2e86f8fd0843cfa02/natsort-7.0.1-py3-none-any.whl
# Collecting nbconvert (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl (455kB)
# Collecting qtconsole (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/42/63/08c241c351d527089083002f65905b81457fc5849fb87cafb08f2a00b354/qtconsole-4.7.5-py2.py3-none-any.whl (118kB)
# Collecting ipykernel (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/51/84/eed2d91a20baf5fbbebd8380e3ec79092fd69c0af3a14a4393bf20287387/ipykernel-5.3.2-py3-none-any.whl (120kB)
# Collecting jupyter-console (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/0a/89/742fa5a80b552ffcb6a8922712697c6e6828aee7b91ee4ae2b79f00f8401/jupyter_console-6.1.0-py2.py3-none-any.whl
# Collecting notebook (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/b1/f1/0a67f09ef53a342403ffa66646ee39273e0ac79ffa5de5dbe2f3e28b5bdf/notebook-6.0.3-py3-none-any.whl (9.7MB)
# Collecting ipywidgets (from jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl (121kB)
# Collecting SecretStorage>=3; sys_platform == "linux" (from keyring>=18.0.1->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/c3/50/8a02cad020e949e6d7105f5f4530d41e3febcaa5b73f8f2148aacb3aeba5/SecretStorage-3.1.2-py3-none-any.whl
# Collecting jeepney>=0.4.2; sys_platform == "linux" (from keyring>=18.0.1->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/79/31/2e8d42727595faf224c6dbb748c32b192e212f25495fe841fb7ce8e168b8/jeepney-0.4.3-py3-none-any.whl
# Collecting entrypoints (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting ansiwrap (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/03/50/43e775a63e0d632d9be3b3fa1c9b2cbaf3b7870d203655710a3426f47c26/ansiwrap-0.8.4-py2.py3-none-any.whl
# Collecting black (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/fd/bb/ad34bbc93d1bea3de086d7c59e528d4a503ac8fe318bd1fa48605584c3d2/black-19.10b0-py36-none-any.whl (97kB)
# Collecting nbformat (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/4d/d1/b568bd35f95321f152f594b3647cd080e96d3347843ff2fa34dce871b8bf/nbformat-5.0.7-py3-none-any.whl (170kB)
# Collecting pyyaml (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
# Collecting tenacity (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/b5/05/ff089032442058bd3386f9cd991cd88ccac81dca1494d78751621ee35e62/tenacity-6.2.0-py2.py3-none-any.whl
# Collecting jupyter-client (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/93/4b/26eabcf24b3e7cfdf063858609af45eecea245cf64d82e2fc88d2ef57857/jupyter_client-6.1.5-py3-none-any.whl (107kB)
# Collecting tqdm>=4.32.2 (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/46/62/7663894f67ac5a41a0d8812d78d9d2a9404124051885af9d77dc526fb399/tqdm-4.47.0-py2.py3-none-any.whl (66kB)
# Collecting nbclient>=0.2.0 (from papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/8d/c5/52e739e4de2553d4ca0780c17e2311285dda4ba7e3d4205e8844ad48a426/nbclient-0.4.0-py3-none-any.whl (63kB)
# Collecting py4j==0.10.9 (from pyspark>=2.4.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.18.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl (156kB)
# Collecting chardet<4,>=3.0.2 (from requests<3.0.0,>=2.18.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<3,>=2.5 (from requests<3.0.0,>=2.18.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
# Collecting pyparsing>=2.0.2 (from packaging->pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
# Collecting zipp>=0.5 (from importlib-metadata>=0.12; python_version < "3.8"->pytest->-r /root/requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting ipython-genutils (from traitlets>=4.2->ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting ptyprocess>=0.5 (from pexpect; sys_platform != "win32"->ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting parso<0.8.0,>=0.7.0 (from jedi>=0.10->ipython->-r /root/requirements.txt (line 15))
#   Downloading https://files.pythonhosted.org/packages/b5/61/998cce9e7476de000d031874df26a18f67cb73448164fc44a98f0c55920b/parso-0.7.0-py2.py3-none-any.whl (100kB)
# Collecting docutils<0.16,>=0.10 (from botocore<1.18.0,>=1.17.19->boto3<2.0,>=1.4.4->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Using cached https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl
# Collecting testpath (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl (163kB)
# Collecting jinja2>=2.4 (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
# Collecting bleach (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl (151kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting defusedxml (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting jupyter-core (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl (83kB)
# Collecting mistune<2,>=0.8.1 (from nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting qtpy (from qtconsole->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/cd/fd/9972948f02e967b691cc0ca1f26124826a3b88cb38f412a8b7935b8c3c72/QtPy-1.9.0-py2.py3-none-any.whl (54kB)
# Collecting pyzmq>=17.1 (from qtconsole->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/c9/11/bb28199dd8f186a4053b7dd94a33abf0c1162d99203e7ab32a6b71fa045b/pyzmq-19.0.1-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
# Collecting tornado>=4.2 (from ipykernel->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
# Collecting prometheus-client (from notebook->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/3f/0e/554a265ffdc56e1494ef08e18f765b0cdec78797f510c58c45cf37abb4f4/prometheus_client-0.8.0-py2.py3-none-any.whl (53kB)
# Collecting Send2Trash (from notebook->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting terminado>=0.8.1 (from notebook->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ff/96/1d9a2c23990aea8f8e0b5c3b6627d03196a73771a17a2d9860bbe9823ab6/terminado-0.8.3-py2.py3-none-any.whl
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/6c/7b/7ac231c20d2d33c445eaacf8a433f4e22c60677eb9776c7c5262d7ddee2d/widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2MB)
# Collecting cryptography (from SecretStorage>=3; sys_platform == "linux"->keyring>=18.0.1->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/58/95/f1282ca55649b60afcf617e1e2ca384a2a3e7a5cf91f724cf83c8fbe76a1/cryptography-2.9.2-cp35-abi3-manylinux1_x86_64.whl (2.7MB)
# Collecting textwrap3>=0.9.2 (from ansiwrap->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/77/9c/a53e561d496ee5866bbeea4d3a850b3b545ed854f8a21007c1e0d872e94d/textwrap3-0.9.2-py2.py3-none-any.whl
# Collecting regex (from black->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f2/86/461fa59347051f378e661fcaf0a6d793450c779f4a29f338ae37c52d8575/regex-2020.6.8-cp36-cp36m-manylinux1_x86_64.whl (660kB)
# Collecting toml>=0.9.4 (from black->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9f/e1/1b40b80f2e1663a6b9f497123c11d7d988c0919abbf3c3f2688e448c5363/toml-0.10.1-py2.py3-none-any.whl
# Collecting appdirs (from black->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting pathspec<1,>=0.6 (from black->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/5d/d0/887c58853bd4b6ffc7aa9cdba4fc57d7b979b45888a6bd47e4568e1cf868/pathspec-0.8.0-py2.py3-none-any.whl
# Collecting typed-ast>=1.4.0 (from black->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/90/ed/5459080d95eb87a02fe860d447197be63b6e2b5e9ff73c2b0a85622994f4/typed_ast-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (737kB)
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting nest-asyncio (from nbclient>=0.2.0->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/74/b4/b24e0a271fb78990c2c62238321686454824b1357ce7abcf20f431fd903d/nest_asyncio-1.3.3-py3-none-any.whl
# Collecting async-generator (from nbclient>=0.2.0->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/71/52/39d20e03abd0ac9159c162ec24b93fbcaa111e8400308f2465432495ca2b/async_generator-1.10-py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2>=2.4->nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting webencodings (from bleach->nbconvert->jupyter>=1.0.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting cffi!=1.11.3,>=1.8 (from cryptography->SecretStorage>=3; sys_platform == "linux"->keyring>=18.0.1->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f1/c7/72abda280893609e1ddfff90f8064568bd8bcb2c1770a9d5bb5edb2d1fea/cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399kB)
# Collecting pyrsistent>=0.14.0 (from jsonschema!=2.5.0,>=2.4->nbformat->papermill>=1.2.0->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/9f/0d/cbca4d0bbc5671822a59f270e4ce3f2195f8a899c97d0d5abb81b191efb5/pyrsistent-0.16.0.tar.gz (108kB)
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography->SecretStorage>=3; sys_platform == "linux"->keyring>=18.0.1->flytekit==0.10.1->-r /root/requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl (112kB)
# Building wheels for collected packages: k8s-proto, pyspark, wrapt, pandocfilters, tornado, pyrsistent
#   Running setup.py bdist_wheel for k8s-proto: started
#   Running setup.py bdist_wheel for k8s-proto: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/8f/44/dc/178781d60d890a85a4de5784894f3224c4c6689a524a91e270
#   Running setup.py bdist_wheel for pyspark: started
#   Running setup.py bdist_wheel for pyspark: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/57/27/4d/ddacf7143f8d5b76c45c61ee2e43d9f8492fc5a8e78ebd7d37
#   Running setup.py bdist_wheel for wrapt: started
#   Running setup.py bdist_wheel for wrapt: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/b1/c2/ed/d62208260edbd3fa7156545c00ef966f45f2063d0a84f8208a
#   Running setup.py bdist_wheel for pandocfilters: started
#   Running setup.py bdist_wheel for pandocfilters: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/39/01/56/f1b08a6275acc59e846fa4c1e1b65dbc1919f20157d9e66c20
#   Running setup.py bdist_wheel for tornado: started
#   Running setup.py bdist_wheel for tornado: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Running setup.py bdist_wheel for pyrsistent: started
#   Running setup.py bdist_wheel for pyrsistent: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/c2/85/ad/bc6d41e2c4b35c9fdfed48f0fcd411ffc4164e67755ddf9ebb
# Successfully built k8s-proto pyspark wrapt pandocfilters tornado pyrsistent
# Installing collected packages: docutils, urllib3, jmespath, six, python-dateutil, botocore, s3transfer, boto3, click, natsort, croniter, wrapt, deprecated, protobuf, flyteidl, grpcio, ipython-genutils, decorator, traitlets, testpath, pygments, MarkupSafe, jinja2, webencodings, pyparsing, packaging, bleach, pandocfilters, defusedxml, entrypoints, jupyter-core, mistune, pyrsistent, zipp, importlib-metadata, attrs, jsonschema, nbformat, nbconvert, tornado, pyzmq, jupyter-client, qtpy, wcwidth, prompt-toolkit, ptyprocess, pexpect, pickleshare, parso, jedi, backcall, ipython, ipykernel, qtconsole, jupyter-console, prometheus-client, Send2Trash, terminado, notebook, widgetsnbextension, ipywidgets, jupyter, pycparser, cffi, cryptography, jeepney, SecretStorage, keyring, textwrap3, ansiwrap, regex, toml, appdirs, pathspec, typed-ast, black, pyyaml, tenacity, tqdm, nest-asyncio, async-generator, nbclient, certifi, chardet, idna, requests, papermill, py4j, pyspark, pytimeparse, pytz, responses, sortedcontainers, statsd, deprecation, numpy, pyarrow, pandas, k8s-proto, flytekit, pluggy, more-itertools, py, pytest, opencv-python
# Successfully installed MarkupSafe-1.1.1 SecretStorage-3.1.2 Send2Trash-1.5.0 ansiwrap-0.8.4 appdirs-1.4.4 async-generator-1.10 attrs-19.3.0 backcall-0.2.0 black-19.10b0 bleach-3.1.5 boto3-1.14.19 botocore-1.17.19 certifi-2020.6.20 cffi-1.14.0 chardet-3.0.4 click-7.1.2 croniter-0.3.34 cryptography-2.9.2 decorator-4.4.2 defusedxml-0.6.0 deprecated-1.2.10 deprecation-2.1.0 docutils-0.15.2 entrypoints-0.3 flyteidl-0.17.36 flytekit-0.8.2 grpcio-1.27.2 idna-2.10 importlib-metadata-1.7.0 ipykernel-5.3.2 ipython-7.16.1 ipython-genutils-0.2.0 ipywidgets-7.5.1 jedi-0.17.1 jeepney-0.4.3 jinja2-2.11.2 jmespath-0.10.0 jsonschema-3.2.0 jupyter-1.0.0 jupyter-client-6.1.5 jupyter-console-6.1.0 jupyter-core-4.6.3 k8s-proto-0.0.3 keyring-21.2.1 mistune-0.8.4 more-itertools-8.4.0 natsort-7.0.1 nbclient-0.4.0 nbconvert-5.6.1 nbformat-5.0.7 nest-asyncio-1.3.3 notebook-6.0.3 numpy-1.19.0 opencv-python-3.4.4.19 packaging-20.4 pandas-1.0.5 pandocfilters-1.4.2 papermill-2.1.2 parso-0.7.0 pathspec-0.8.0 pexpect-4.8.0 pickleshare-0.7.5 pluggy-0.13.1 prometheus-client-0.8.0 prompt-toolkit-3.0.5 protobuf-3.12.2 ptyprocess-0.6.0 py-1.9.0 py4j-0.10.9 pyarrow-0.17.1 pycparser-2.20 pygments-2.6.1 pyparsing-2.4.7 pyrsistent-0.16.0 pyspark-3.0.0 pytest-5.4.3 python-dateutil-2.8.1 pytimeparse-1.1.8 pytz-2018.4 pyyaml-5.3.1 pyzmq-19.0.1 qtconsole-4.7.5 qtpy-1.9.0 regex-2020.6.8 requests-2.24.0 responses-0.10.15 s3transfer-0.3.3 six-1.15.0 sortedcontainers-2.2.2 statsd-3.3.0 tenacity-6.2.0 terminado-0.8.3 testpath-0.4.4 textwrap3-0.9.2 toml-0.10.1 tornado-6.0.4 tqdm-4.47.0 traitlets-4.3.3 typed-ast-1.4.1 urllib3-1.24.3 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.5.1 wrapt-1.12.1 zipp-3.1.0
# Error processing tar file(exit status 1): write /root/.cache/pip/http/7/e/5/8/6/7e5860f4a1086b475b819a0553bf1e9e82ca7312dfb5f963e521e11b: no space left on device
# The push refers to repository [docker.io/lyft/flytesnacks]
#
# 2cac9ffb: Preparing
# f845a7fb: Preparing
# 543bcece: Preparing
# 1535116a: Preparing
# bb51655e: Preparing
# e9699b3b: Preparing
# b7640e73: Waiting g
# 02118bd7: Preparing
# 02118bd7: Waiting g
# afb09dc3: Preparing
# b5a53aac: Waiting g
# c8e5063e: Preparing
# 7c529ced: Layer already exists datacouncil-24: digest: sha256:21bfaf494320ca055107d25459d598d4632651be5463fe347e15e99fdb411452 size: 3251

# %% [markdown]
# ### 2) Register a notebook task
# FlyteKit can discover all tasks, workflows and launchplans in a given python package(s). You can use flytekit.clis.sdk_in_container.register.register_all to achieve that.

# %%
from os import environ
from flytekit.configuration import set_flyte_config_file
from flytekit.contrib.notebook import python_notebook, spark_notebook
from flytekit.sdk.types import Types
from workflows.recipe_7.interactive_python import interactive_python

environ["FLYTE_INTERNAL_IMAGE"] = "docker.io/lyft/flytesnacks:datacouncil-{}".format(environ["version"])
set_flyte_config_file("sandbox.config")
environ["FLYTE_INTERNAL_CONFIGURATION_PATH"] = "/root/sandbox.config"

interactive_python.register(project="flytesnacks", domain="development", name="interactive_python", version=environ["version"])
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# <ipython-input-5-2f598fe67336> in <module>
#       9 environ["FLYTE_INTERNAL_CONFIGURATION_PATH"] = "/root/sandbox.config"
#      10
# ---> 11 interactive_python.register(project="flytesnacks", domain="development", name="interactive_python", version=environ["version"])
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/common/exceptions/scopes.py in system_entry_point(wrapped, instance, args, kwargs)
#     159         if _is_base_context():
#     160             try:
# --> 161                 return wrapped(*args, **kwargs)
#     162             except FlyteScopedException as ex:
#     163                 _reraise(ex.type, ex.value, ex.traceback)
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/common/tasks/task.py in register(self, project, domain, name, version)
#     153         try:
#     154             self._id = id_to_register
# --> 155             _engine_loader.get_engine().get_task(self).register(id_to_register)
#     156             return _six.text_type(self.id)
#     157         except:
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/engines/flyte/engine.py in register(self, identifier)
#     263                 identifier,
#     264                 _task_models.TaskSpec(
# --> 265                     self.sdk_task
#     266                 )
#     267             )
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/clients/friendly.py in create_task(self, task_identifer, task_spec)
#      59             _task_pb2.TaskCreateRequest(
#      60                 id=task_identifer.to_flyte_idl(),
# ---> 61                 spec=task_spec.to_flyte_idl()
#      62             )
#      63         )
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/clients/raw.py in handler(*args, **kwargs)
#      77             for i in range(retries):
#      78                 try:
# ---> 79                     return fn(*args, **kwargs)
#      80                 except _RpcError as e:
#      81                     if e.code() == _GrpcStatusCode.UNAUTHENTICATED:
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/clients/raw.py in handler(self, create_request)
#     105
#     106             # In any case, re-raise since we're not truly handling the error here
# --> 107             raise e
#     108
#     109     return handler
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/clients/raw.py in handler(self, create_request)
#      98     def handler(self, create_request):
#      99         try:
# --> 100             fn(self, create_request)
#     101         except _RpcError as e:
#     102             if e.code() == _GrpcStatusCode.INVALID_ARGUMENT:
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/flytekit/clients/raw.py in create_task(self, task_create_request)
#     180         :raises grpc.RpcError:
#     181         """
# --> 182         return self._stub.CreateTask(task_create_request, metadata=self._metadata)
#     183
#     184     @_handle_rpc_error
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     822         state, call, = self._blocking(request, timeout, metadata, credentials,
#     823                                       wait_for_ready, compression)
# --> 824         return _end_unary_response_blocking(state, call, False, None)
#     825
#     826     def with_call(self,
#
# ~/.virtualenvs/flytekit-py32/lib/python3.7/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     724             return state.response
#     725     else:
# --> 726         raise _InactiveRpcError(state)
#     727
#     728
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "DNS resolution failed"
# 	debug_error_string = "{"created":"@1594312200.873644000","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3941,"referenced_errors":[{"created":"@1594312185.408302000","description":"Resolver transient failure","file":"src/core/ext/filters/client_channel/resolving_lb_policy.cc","file_line":262,"referenced_errors":[{"created":"@1594312185.408300000","description":"DNS resolution failed","file":"src/core/ext/filters/client_channel/resolver/dns/c_ares/dns_resolver_ares.cc","file_line":370,"grpc_status":14,"referenced_errors":[{"created":"@1594312185.408245000","description":"C-ares status is not ARES_SUCCESS: Domain name not found","file":"src/core/ext/filters/client_channel/resolver/dns/c_ares/grpc_ares_wrapper.cc","file_line":244,"referenced_errors":[{"created":"@1594312185.408234000","description":"C-ares status is not ARES_SUCCESS: Domain name not found","file":"src/core/ext/filters/client_channel/resolver/dns/c_ares/grpc_ares_wrapper.cc","file_line":244}]}]}]}]}"
# >

# %% [markdown]
# ### 3) Launch a single task
# This action runs the task on a flyte cluster (KinD, Docker for Desktop, EKS, GKE,... etc.)

# %%
from workflows.recipe_1.inner import IdentityWorkflow
from os import environ

exec = interactive_python.launch(project="flytesnacks", domain="development", inputs={
    'a': 5.0,
    'b': 6.0,
})
print_console_url(exec)
# Out:
# http://flyte.lyft.net/console/projects/flytesnacks/domains/development/executions/ufsh8uh8c7

# %%
print("Waiting for workflow execution to complete")
exec.wait_for_completion()
print("Done!")
print()
print("Output: {}".format(exec.outputs["out"]))
# Out:
# Waiting for workflow execution to complete
# Done!
#
# Output: 11.0
